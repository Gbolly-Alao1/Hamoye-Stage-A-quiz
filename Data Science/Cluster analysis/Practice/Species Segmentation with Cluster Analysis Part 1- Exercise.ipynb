# %% [markdown]
# # Species Segmentation with Cluster Analysis

# %% [markdown]
# The Iris flower dataset is one of the most popular ones for machine learning. You can read a lot about it online and have probably already heard of it: https://en.wikipedia.org/wiki/Iris_flower_data_set
#
# We didn't want to use it in the lectures, but believe that it would be very interesting for you to try it out (and maybe read about it on your own).
#
# There are 4 features: sepal length, sepal width, petal length, and petal width.
#
# Start by creating 2 clusters. Then standardize the data and try again. Does it make a difference?
#
# Use the Elbow rule to determine how many clusters are there.

# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans
sns.set()

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load data from the csv file: <i> 'iris_dataset.csv'</i>.

# %%
data = pd.read_csv('iris_dataset.csv')

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ## Plot the data

# %% [markdown]
# For this exercise, try to cluster the iris flowers by the shape of their sepal.
#
# <i> Use the 'sepal_length' and 'sepal_width' variables.</i>

# %%
plt.scatter(data['sepal_length'], data['sepal_width'])
plt.xlabel('Sepal length', c = "red", fontsize = 20)
plt.ylabel('Sepal width', c = 'red', fontsize = 20)
# Out:
# Text(0, 0.5, 'Sepal width')

# %% [markdown]
# # Clustering (unscaled data)

# %% [markdown]
# Separate the original data into 2 clusters.

# %%
x = data.copy()
kmeans = KMeans(2)
kmeans.fit(x)
# Out:
# KMeans(n_clusters=2)

# %%
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
x.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data_with_cluster = data.copy()
data_with_cluster['Clusters'] = kmeans.fit_predict(x)
data_with_cluster
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  Clusters
# 0             5.1          3.5           1.4          0.2         1
# 1             4.9          3.0           1.4          0.2         1
# 2             4.7          3.2           1.3          0.2         1
# 3             4.6          3.1           1.5          0.2         1
# 4             5.0          3.6           1.4          0.2         1
# ..            ...          ...           ...          ...       ...
# 145           6.7          3.0           5.2          2.3         0
# 146           6.3          2.5           5.0          1.9         0
# 147           6.5          3.0           5.2          2.0         0
# 148           6.2          3.4           5.4          2.3         0
# 149           5.9          3.0           5.1          1.8         0
#
# [150 rows x 5 columns]

# %%
plt.scatter(data['sepal_length'], data['sepal_width'], c = data_with_cluster['Clusters'], cmap = 'rainbow')
plt.xlabel('Sepal length', c = "red", fontsize = 20)
plt.ylabel('Sepal width', c = 'red', fontsize = 20)
# Out:
# Text(0, 0.5, 'Sepal width')

# %% [markdown]
# # Standardize the variables

# %% [markdown]
# Import and use the <i> method </i> function from sklearn to standardize the data.

# %%
from sklearn import preprocessing
# Scale the inputs
# preprocessing.scale scales each variable (column in x) with respect to itself
# The new result is an array
x_scaled = preprocessing.scale(x)
x_scaled
# Out:
# array([[-9.00681170e-01,  1.03205722e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00, -1.24957601e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.38535265e+00,  3.37848329e-01, -1.39813811e+00,
#         -1.31297673e+00],
#        [-1.50652052e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.02184904e+00,  1.26346019e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-5.37177559e-01,  1.95766909e+00, -1.17067529e+00,
#         -1.05003079e+00],
#        [-1.50652052e+00,  8.00654259e-01, -1.34127240e+00,
#         -1.18150376e+00],
#        [-1.02184904e+00,  8.00654259e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.74885626e+00, -3.56360566e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.44444970e+00],
#        [-5.37177559e-01,  1.49486315e+00, -1.28440670e+00,
#         -1.31297673e+00],
# ...

# %% [markdown]
# # Clustering (scaled data)

# %%
kmeans_new = KMeans(2)
kmeans_new.fit(x_scaled)
# Out:
# KMeans(n_clusters=2)

# %%
cluster_new = x.copy()
cluster_new['Clusters'] = kmeans_new.fit_predict(x_scaled)
cluster_new
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  Clusters
# 0             5.1          3.5           1.4          0.2         0
# 1             4.9          3.0           1.4          0.2         0
# 2             4.7          3.2           1.3          0.2         0
# 3             4.6          3.1           1.5          0.2         0
# 4             5.0          3.6           1.4          0.2         0
# ..            ...          ...           ...          ...       ...
# 145           6.7          3.0           5.2          2.3         1
# 146           6.3          2.5           5.0          1.9         1
# 147           6.5          3.0           5.2          2.0         1
# 148           6.2          3.4           5.4          2.3         1
# 149           5.9          3.0           5.1          1.8         1
#
# [150 rows x 5 columns]

# %%
plt.scatter(cluster_new['sepal_length'], cluster_new['sepal_width'], c = cluster_new['Clusters'], cmap = 'rainbow')
plt.xlabel('Sepal length', c = "red", fontsize = 20)
plt.ylabel('Sepal width', c = 'red', fontsize = 20)
# Out:
# Text(0, 0.5, 'Sepal width')

# %% [markdown]
# ## Take Advantage of the Elbow Method

# %% [markdown]
# ### WCSS

# %%
wcss = []

for i in range(1,11):
    kmeans = KMeans(i)
    kmeans.fit(x_scaled)
    wcss.append(kmeans.inertia_)

# %%
wcss
# Out:
# [600.0000000000003,
#  223.73200573676343,
#  140.96581663074699,
#  114.61550694959811,
#  91.1543680779766,
#  80.53520939466797,
#  70.88546993521874,
#  63.772145022411856,
#  55.679908540341735,
#  47.399003905035876]

# %% [markdown]
# ### The Elbow Method

# %%
no_clusters = range(1,11)
plt.plot(no_clusters, wcss, c = 'red')
plt.title('The Elbow Method', c = 'Orange', fontsize = 15)
plt.xlabel('Number of clusters', c = 'blue', fontsize = 20)
plt.ylabel('WCSS', c = 'blue', fontsize = 20)
# Out:
# Text(0, 0.5, 'WCSS')

# %% [markdown]
# How many clusters are there?
