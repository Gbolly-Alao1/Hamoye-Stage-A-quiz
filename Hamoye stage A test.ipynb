# %%
import pandas as pd
import seaborn as sns
sns.set()

# %%
data_df = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='Latin-1')

# %%
data_df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
data_df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
new = data_df.groupby('Item')['Item'].count()

# %%
new
# Out:
# Item
# Alcohol, Non-Food      283
# Alcoholic Beverages    564
# Animal Products        135
# Animal fats            639
# Apples and products    517
#                       ...
# Vegetables, Other      583
# Vegetal Products       135
# Wheat and products     653
# Wine                   497
# Yams                   383
# Name: Item, Length: 119, dtype: int64

# %%
new1 = data_df.groupby('Element')['Element'].count()

# %%
new_data_df = data_df[['Y2017', 'Y2018']]

# %%
new_data_df.head()
# Out:
#       Y2017     Y2018
# 0  41389.00  42228.00
# 1      0.00      0.00
# 2   3341.00   3322.00
# 3     92.82     91.83
# 4     80.19     77.28

# %%
sns.regplot(x = 'Y2017', y = 'Y2018', data = new_data_df)
# Out:
# <AxesSubplot:xlabel='Y2017', ylabel='Y2018'>

# %%
data2 = pd.read_csv('Foreign_Exchange_Rates.csv')

# %%
data2.describe()
# Out:
#         Unnamed: 0
# count  5217.000000
# mean   2608.000000
# std    1506.162508
# min       0.000000
# 25%    1304.000000
# 50%    2608.000000
# 75%    3912.000000
# max    5216.000000

# %%
data2.head()
# Out:
#    Unnamed: 0  Time Serie AUSTRALIA - AUSTRALIAN DOLLAR/US$  \
# 0           0  2000-01-03                            1.5172
# 1           1  2000-01-04                            1.5239
# 2           2  2000-01-05                            1.5267
# 3           3  2000-01-06                            1.5291
# 4           4  2000-01-07                            1.5272
#
#   EURO AREA - EURO/US$ NEW ZEALAND - NEW ZELAND DOLLAR/US$  \
# 0               0.9847                              1.9033
# 1                 0.97                              1.9238
# 2               0.9676                              1.9339
# 3               0.9686                              1.9436
# 4               0.9714                               1.938
#
#   UNITED KINGDOM - UNITED KINGDOM POUND/US$ BRAZIL - REAL/US$  \
# 0                                    0.6146             1.805
# 1                                    0.6109            1.8405
# ...

# %%
data2.isnull().sum()
# Out:
# Unnamed: 0                                   0
# Time Serie                                   0
# AUSTRALIA - AUSTRALIAN DOLLAR/US$            0
# EURO AREA - EURO/US$                         0
# NEW ZEALAND - NEW ZELAND DOLLAR/US$          0
# UNITED KINGDOM - UNITED KINGDOM POUND/US$    0
# BRAZIL - REAL/US$                            0
# CANADA - CANADIAN DOLLAR/US$                 0
# CHINA - YUAN/US$                             0
# HONG KONG - HONG KONG DOLLAR/US$             0
# INDIA - INDIAN RUPEE/US$                     0
# KOREA - WON/US$                              0
# MEXICO - MEXICAN PESO/US$                    0
# SOUTH AFRICA - RAND/US$                      0
# SINGAPORE - SINGAPORE DOLLAR/US$             0
# DENMARK - DANISH KRONE/US$                   0
# JAPAN - YEN/US$                              0
# MALAYSIA - RINGGIT/US$                       0
# NORWAY - NORWEGIAN KRONE/US$                 0
# SWEDEN - KRONA/US$                           0
# ...

# %%
data2.count()
# Out:
# Unnamed: 0                                   5217
# Time Serie                                   5217
# AUSTRALIA - AUSTRALIAN DOLLAR/US$            5217
# EURO AREA - EURO/US$                         5217
# NEW ZEALAND - NEW ZELAND DOLLAR/US$          5217
# UNITED KINGDOM - UNITED KINGDOM POUND/US$    5217
# BRAZIL - REAL/US$                            5217
# CANADA - CANADIAN DOLLAR/US$                 5217
# CHINA - YUAN/US$                             5217
# HONG KONG - HONG KONG DOLLAR/US$             5217
# INDIA - INDIAN RUPEE/US$                     5217
# KOREA - WON/US$                              5217
# MEXICO - MEXICAN PESO/US$                    5217
# SOUTH AFRICA - RAND/US$                      5217
# SINGAPORE - SINGAPORE DOLLAR/US$             5217
# DENMARK - DANISH KRONE/US$                   5217
# JAPAN - YEN/US$                              5217
# MALAYSIA - RINGGIT/US$                       5217
# NORWAY - NORWEGIAN KRONE/US$                 5217
# ...
